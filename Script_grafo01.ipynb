# %% [markdown]
# <a href="https://colab.research.google.com/github/Jorge2018/Grafos_Python/blob/main/Script_grafo01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv(r'https://raw.githubusercontent.com/Jorge2018/DataScience2022-2/main/GHG-emissions-by-life-cycle-stage-OurWorldinData-upload.csv')
x1 = df['Food product']
y1 = df['Farm']
plt.figure(dpi=190)
plt.plot(x1, y1, label = "$y_1 -> Tab1$" )
plt.xlabel("x")
plt.ylabel("y")
plt.xticks(rotation=90,fontsize=6)
plt.grid()
plt.show()
